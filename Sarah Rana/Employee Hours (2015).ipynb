# %%
import pandas as pd 
import numpy as np 
import statistics

# %%
# import in_time data
df = pd.read_csv(r'C:\Users\SarahRana\OneDrive - JCW Resourcing\Documents\Datasets\in_time.csv', index_col=0)
df = pd.read_csv(r'C:\Users\SarahRana\OneDrive - JCW Resourcing\Documents\Datasets\in_time.csv', index_col=0,parse_dates=list(range(len(df.columns)+1)) )

# %%
# import out_time data
da = pd.read_csv(r'C:\Users\SarahRana\OneDrive - JCW Resourcing\Documents\Datasets\out_time.csv', index_col=0,parse_dates=list(range(len(df.columns)+1)) )

# %%
df.dropna(axis=1,how='all',inplace=True) #in_time

# %%
da.dropna(axis=1,how='all',inplace=True) #out_time

# %%
arr1=df.to_numpy(copy=True)
arr2=da.to_numpy(copy=True)

# %%
arr1
# Out:
# array([['2015-01-02T09:43:45.000000000', '2015-01-05T10:08:48.000000000',
#         '2015-01-06T09:54:26.000000000', ...,
#         '2015-12-29T10:03:36.000000000', '2015-12-30T09:54:12.000000000',
#         '2015-12-31T10:12:44.000000000'],
#        ['2015-01-02T10:15:44.000000000', '2015-01-05T10:21:05.000000000',
#                                   'NaT', ...,
#         '2015-12-29T09:55:49.000000000', '2015-12-30T10:32:25.000000000',
#         '2015-12-31T09:27:20.000000000'],
#        ['2015-01-02T10:17:41.000000000', '2015-01-05T09:50:50.000000000',
#         '2015-01-06T10:14:13.000000000', ...,
#         '2015-12-29T09:43:36.000000000', '2015-12-30T09:34:05.000000000',
#         '2015-12-31T10:28:39.000000000'],
#        ...,
#        ['2015-01-02T10:01:01.000000000', '2015-01-05T09:33:00.000000000',
#         '2015-01-06T09:49:17.000000000', ...,
#                                   'NaT', '2015-12-30T10:02:36.000000000',
#         '2015-12-31T10:03:30.000000000'],
# ...

# %%
arr=arr2-arr1

# %%
final_df=pd.DataFrame(arr,columns=list(df.columns))

# %%
final_df.index = final_df.index + 1 #reset index starting from 1 to match EmployeeID

# %%
final_df
# Out:
#           2015-01-02      2015-01-05      2015-01-06      2015-01-07  \
# 1    0 days 07:12:30 0 days 07:11:23 0 days 07:24:39 0 days 07:00:24
# 2    0 days 08:06:33 0 days 07:27:17             NaT 0 days 07:23:49
# 3    0 days 06:41:33 0 days 07:15:56 0 days 06:24:19 0 days 06:45:54
# 4    0 days 07:20:18 0 days 07:17:31 0 days 06:56:35 0 days 06:55:10
# 5    0 days 08:03:20 0 days 07:59:17 0 days 07:40:57 0 days 07:48:22
# ...              ...             ...             ...             ...
# 4406 0 days 08:07:05 0 days 08:50:27 0 days 08:23:58 0 days 08:50:42
# 4407 0 days 06:15:20             NaT 0 days 05:23:37 0 days 05:43:40
# 4408 0 days 07:16:34 0 days 07:35:07 0 days 07:38:29 0 days 07:59:10
# 4409 0 days 09:31:32 0 days 09:35:13 0 days 09:47:18 0 days 09:23:28
# 4410 0 days 06:50:10 0 days 07:16:48 0 days 06:43:40 0 days 06:50:32
#
#           2015-01-08      2015-01-09      2015-01-12      2015-01-13  \
# ...

# %%
final_df['mean'] = final_df.mean(axis=1).astype('timedelta64[h]') # calculate mean hours worked

# %%
final_df['attendence'] = final_df.iloc[:,:-1].count(axis=1)

# %%
employee_timekeep=final_df.iloc[:,-2:]

# %%
employee_timekeep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 1 to 4410
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   mean        4410 non-null   float64
#  1   attendence  4410 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 69.0 KB

# %%
employee_timekeep.to_csv('mean_n_attendence.csv')
